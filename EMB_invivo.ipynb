# %%
# ============================================================
# RDKit – manipulação e padronização de moléculas químicas
# ============================================================
from rdkit import Chem, RDLogger
from rdkit.Chem import Descriptors, AllChem
from rdkit.Chem.MolStandardize import rdMolStandardize


# ============================================================
# Utilidades gerais – sistema, regex, datas, progresso e numéricos
# ============================================================
import os
import re
from datetime import datetime
from tqdm import tqdm         # barras de progresso
import joblib                 # salvar/carregar modelos
import numpy as np
import pandas as pd
import torch


# ============================================================
# Transformers – *tokenizers* e modelos pré-treinados (HuggingFace)
# ============================================================
from transformers import AutoTokenizer, AutoModel


# ============================================================
# Scikit-learn – divisão, validação cruzada e *pipelines*
# ============================================================
from sklearn.model_selection import (
    train_test_split, StratifiedKFold, cross_validate, cross_val_score,
    StratifiedGroupKFold
)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer


# ============================================================
# Scikit-learn – métricas de avaliação
# ============================================================
from sklearn.metrics import (
    make_scorer, precision_score, recall_score, f1_score,
    accuracy_score, roc_auc_score, classification_report
)


# ============================================================
# Scikit-learn – modelos lineares
# ============================================================
from sklearn.linear_model import (
    LogisticRegression, RidgeClassifier, SGDClassifier,
    PassiveAggressiveClassifier, Perceptron
)


# ============================================================
# Scikit-learn – Máquinas de Vetores de Suporte (SVM)
# ============================================================
from sklearn.svm import SVC, LinearSVC, NuSVC


# ============================================================
# Scikit-learn – métodos baseados em vizinhos
# ============================================================
from sklearn.neighbors import KNeighborsClassifier


# ============================================================
# Scikit-learn – árvores de decisão e modelos *ensemble*
# ============================================================
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier,
    AdaBoostClassifier, BaggingClassifier, HistGradientBoostingClassifier
)


# ============================================================
# Scikit-learn – modelos Naive Bayes
# ============================================================
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB


# ============================================================
# Scikit-learn – análise discriminante
# ============================================================
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
)


# ============================================================
# Scikit-learn – redes neurais (MLP)
# ============================================================
from sklearn.neural_network import MLPClassifier


# ============================================================
# Modelos externos – gradiente boosting modernos
# ============================================================
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier


# ============================================================
# Imbalanced-learn – tratamento de desbalanceamento
# ============================================================
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

# %%
import importlib

# Lista de módulos e nomes amigáveis
modules = {
    "rdkit": "RDKit",
    "os": "os",
    "re": "re",
    "datetime": "datetime",
    "tqdm": "tqdm",
    "joblib": "joblib",
    "numpy": "numpy",
    "pandas": "pandas",
    "torch": "torch",
    "transformers": "transformers",
    "sklearn": "scikit-learn",
    "xgboost": "xgboost",
    "lightgbm": "lightgbm",
    "catboost": "catboost",
    "imblearn": "imbalanced-learn",
}

def get_version(module_name, friendly_name):
    try:
        module = importlib.import_module(module_name)

        # Tentativa padrão
        if hasattr(module, "__version__"):
            return f"{friendly_name}: {module.__version__}"

        # Casos especiais --------------------------

        # RDKit
        if module_name == "rdkit":
            from rdkit import rdBase
            return f"{friendly_name}: {rdBase.rdkitVersion}"

        # os, re, datetime → módulos padrão não têm versão
        if module_name in ("os", "re", "datetime"):
            return f"{friendly_name}: módulo padrão (sem versão)"

        return f"{friendly_name}: versão não encontrada"

    except Exception as e:
        return f"{friendly_name}: erro ao importar ({e})"


# Printar tudo organizado
print("=== VERSÕES DAS BIBLIOTECAS ===\n")
for mod, name in modules.items():
    print(get_version(mod, name))
# Out:
# === VERSÕES DAS BIBLIOTECAS ===
#
# RDKit: 2025.03.2
# os: módulo padrão (sem versão)
# re: 2.2.1
# datetime: módulo padrão (sem versão)
# tqdm: 4.67.1
# joblib: 1.5.1
# numpy: 2.2.6
# pandas: 2.3.3
# torch: 2.9.1+cu128
# transformers: 4.57.1
# scikit-learn: 1.6.1
# xgboost: 3.0.2
# lightgbm: 4.6.0
# catboost: 1.2.8
# imbalanced-learn: 0.14.0

# %% [markdown]
# # Limpeza de Dados

# %%
# Disable informational messages from RDKit
RDLogger.DisableLog('rdApp.info')

def is_valid_smiles(smiles):
    """
    Checks whether a SMILES string is valid.

    Parameters:
        smiles (str): The SMILES representation of the molecule.

    Returns:
        bool: True if the SMILES is valid, False otherwise.
    """
    # Return False if SMILES is None, not a string, or empty/whitespace only
    if pd.isna(smiles) or not isinstance(smiles, str) or smiles.strip() == "":
        return False

    # Remove leading/trailing spaces
    smiles = smiles.strip()

    try:
        # First, try parsing the SMILES with normal sanitization
        mol = Chem.MolFromSmiles(smiles, sanitize=True)
        if mol is not None:
            return True
    except Exception:
        # Ignore errors here and try without sanitization
        pass  

    try:
        # If normal sanitization fails, parse without sanitization
        mol = Chem.MolFromSmiles(smiles, sanitize=False)
        if mol is not None:
            # Attempt manual sanitization and catch possible errors
            Chem.SanitizeMol(mol, catchErrors=True)
            return True
    except Exception:
        pass

    # If all parsing attempts fail, return False
    return False

# %% [markdown]
# # Vetorização

# %%
#=========================
# FUNÇÃO DE EMBEDDING
#=========================
def embed_model(model_name, smiles_list):

    print(f"\nCarregando modelo: {model_name}")

    tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
    model = AutoModel.from_pretrained(model_name, trust_remote_code=True)
    model.to(device).eval()

    def get_embedding(smiles):
        inputs = tokenizer(smiles, return_tensors="pt", truncation=True, padding=True)
        inputs = {k: v.to(device) for k, v in inputs.items()}
        with torch.no_grad():
            outputs = model(**inputs)
        emb = outputs.last_hidden_state.mean(dim=1).squeeze()
        return emb.cpu().numpy()

    embeddings = [get_embedding(s) for s in tqdm(smiles_list, desc=f"Embeddings {model_name}")]
    return np.vstack(embeddings)

# %% [markdown]
# # dataset

# %% [markdown]
# ## in vivo

# %%
df_vivo= pd.read_csv('in vivo + cpdb.csv')
df_vivo.shape
# Out:
# (19883, 9)

# %%
df_vivo['SMILES_valido'] = df_vivo['SMILES'].apply(is_valid_smiles)
df_vivo['SMILES_valido'].value_counts()
# Out:
# [23:13:23] WARNING: not removing hydrogen atom without neighbors
# [23:13:23] WARNING: not removing hydrogen atom without neighbors
# SMILES_valido
# True    19883
# Name: count, dtype: int64

# %%
# Drop unnecessary columns
df_vivo.drop(columns=['Chemical', 'Identificador', 'SMILES_valido','species',	'strain',	'Male',	'Female'], inplace=True)

# Convert text columns to lowercase
df_vivo['Results'] = df_vivo['Results'].str.lower()
df_vivo['Type'] = df_vivo['Type'].str.lower()

# Remove duplicate rows if any
df_vivo.drop_duplicates(inplace=True)

df_vivo.shape
# Out:
# (3617, 3)

# %%
# Identify SMILES (in the filtered DataFrame) that have more than one 'Results' value
smiles_multiple_results = df_vivo.groupby("SMILES")["Results"].nunique()
smiles_multiple_results = smiles_multiple_results[smiles_multiple_results > 1].index

# Remove SMILES that have more than one result
df_final_vivo = df_vivo[~df_vivo["SMILES"].isin(smiles_multiple_results)]

print("Total de compostos não divergentes:", len(df_final_vivo))

df_organicos = df_final_vivo[df_final_vivo["SMILES"].str.contains(r"C(?![a-z])", regex=True, na=False)]

print("Total de compostos orgânicos:", len(df_organicos))

# Drop 'Type' column as it is no longer needed
df_final_vivo = df_organicos.drop(columns='Type')

# Reset index for clean ordering
df_final_vivo.reset_index(drop=True, inplace=True)

# Show final shape
print("Total de compostos final:", len(df_final_vivo))
# Out:
# Total de compostos não divergentes: 2227
# Total de compostos orgânicos: 2090
# Total de compostos final: 2090

# %% [markdown]
# # Experimentation

# %%
#=========================
# LISTA DE MODELOS
#=========================
model_list = [
    "DeepChem/ChemBERTa-77M-MTR",
    "DeepChem/ChemBERTa-77M-MLM",
    "DeepChem/ChemBERTa-100M-MLM",
    "ibm-research/MoLFormer-XL-both-10pct",
    "seyonec/ChemBERTa-zinc-base-v1",
    "alvaroalon2/biobert_chemical_ner",
    "google-bert/bert-base-uncased"
]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#=========================
# MODELOS CLÁSSICOS
#=========================
model_zoo = {
    "LogisticRegression": LogisticRegression(max_iter=1000, n_jobs=-1),
    "RidgeClassifier": RidgeClassifier(),
    "SGDClassifier": SGDClassifier(max_iter=1000, tol=1e-3, n_jobs=-1),
    "PassiveAggressive": PassiveAggressiveClassifier(max_iter=1000, random_state=42),
    "Perceptron": Perceptron(max_iter=1000, tol=1e-3, random_state=42),

    "LinearSVC": LinearSVC(),
    "SVC": SVC(),
    "NuSVC": NuSVC(),

    "KNeighbors": KNeighborsClassifier(),

    "DecisionTree": DecisionTreeClassifier(random_state=42),
    "ExtraTree": ExtraTreeClassifier(random_state=42),
    "RandomForest": RandomForestClassifier(n_estimators=300, random_state=42, n_jobs=-1),
    "ExtraTrees": ExtraTreesClassifier(n_estimators=300, random_state=42, n_jobs=-1),
    "GradientBoosting": GradientBoostingClassifier(random_state=42),
    "HistGradientBoosting": HistGradientBoostingClassifier(random_state=42),

    "AdaBoost": AdaBoostClassifier(random_state=42),
    "Bagging": BaggingClassifier(random_state=42, n_jobs=-1),

    "GaussianNB": GaussianNB(),
    "BernoulliNB": BernoulliNB(),

    "LDA": LinearDiscriminantAnalysis(),
    "QDA": QuadraticDiscriminantAnalysis(),

    "MLPClassifier": MLPClassifier(max_iter=1000, random_state=42),

    "XGBoost": XGBClassifier(
        n_estimators=500, learning_rate=0.05, max_depth=6,
        subsample=0.8, colsample_bytree=0.8, random_state=42,
        use_label_encoder=False, eval_metric="logloss", n_jobs=-1
    ),

    "LightGBM": LGBMClassifier(
        n_estimators=500, learning_rate=0.05, max_depth=-1,
        subsample=0.8, colsample_bytree=0.8, random_state=42, n_jobs=-1
    ),

    "CatBoost": CatBoostClassifier(
        iterations=500, learning_rate=0.05, depth=6, verbose=False, random_state=42
    )
}

#=========================
# CROSS VALIDATION
#=========================
cv = StratifiedGroupKFold(n_splits=10, shuffle=True, random_state=42)

scoring = {
    "accuracy": "accuracy",
    "balanced_accuracy": "balanced_accuracy",
    "f1": "f1",
    "roc_auc": "roc_auc",
    "precision": "precision",
    "recall": "recall",
}

#=========================
# BALANCEAMENTOS
#=========================
balancers = {
    "original": None,
    "under": RandomUnderSampler(random_state=42),
    "over": RandomOverSampler(random_state=42),
    "smooth": SMOTE(random_state=42)
}

#=========================
# LOOP PRINCIPAL
#=========================
os.makedirs("Resultados", exist_ok=True)
os.makedirs("Resultados_folds", exist_ok=True)

for model_name in model_list:

    smiles_list = df_final_vivo["SMILES"].tolist()
    embeddings = embed_model(model_name, smiles_list)

    X = pd.DataFrame(embeddings).fillna(0)
    y = df_final_vivo["Results"].astype(str).str.lower().map({"positive": 1, "negative": 0})
    groups = df_final_vivo["SMILES"].values

    for balance_name, sampler in balancers.items():

        print(f"\nRodando sampling {balance_name} no modelo {model_name}")

        pipelines = {}

        for name, clf in model_zoo.items():
            steps = [("scaler", StandardScaler())]

            if sampler is not None:
                steps.append(("sampler", sampler))

            steps.append(("clf", clf))
            pipelines[name] = ImbPipeline(steps=steps)

        # ==============================
        # LISTAS PARA SALVAMENTO
        # ==============================
        summary_rows = []   # médias e std
        fold_rows = []      # resultados fold a fold

        for name, pipe in pipelines.items():

            cvres = cross_validate(
                pipe, X, y,
                cv=cv,
                scoring=scoring,
                n_jobs=-1,
                groups=groups,
                return_train_score=False
            )

            # ---------------------------
            # SALVAR FOLDS INDIVIDUAIS
            # ---------------------------
            for i in range(cv.get_n_splits()):
                fold_rows.append({
                    "EmbeddingModel": model_name,
                    "Balance": balance_name,
                    "Model": name,
                    "Fold": i + 1,
                    "Accuracy": cvres["test_accuracy"][i],
                    "BalancedAcc": cvres["test_balanced_accuracy"][i],
                    "F1": cvres["test_f1"][i],
                    "ROC_AUC": cvres["test_roc_auc"][i],
                    "Precision": cvres["test_precision"][i],
                    "Recall": cvres["test_recall"][i],
                    "FitTime": cvres["fit_time"][i],
                    "ScoreTime": cvres["score_time"][i],
                })

            # ---------------------------
            # SALVAR MÉDIA E STD
            # ---------------------------
            summary_rows.append({
                "EmbeddingModel": model_name,
                "Balance": balance_name,
                "Model": name,
                "Accuracy_mean": np.mean(cvres["test_accuracy"]),
                "Accuracy_std":  np.std(cvres["test_accuracy"], ddof=1),
                "BalAcc_mean":   np.mean(cvres["test_balanced_accuracy"]),
                "BalAcc_std":    np.std(cvres["test_balanced_accuracy"], ddof=1),
                "F1_mean":       np.mean(cvres["test_f1"]),
                "F1_std":        np.std(cvres["test_f1"], ddof=1),
                "ROC_AUC_mean":  np.mean(cvres["test_roc_auc"]),
                "ROC_AUC_std":   np.std(cvres["test_roc_auc"], ddof=1),
                "Precision_mean":np.mean(cvres["test_precision"]),
                "Precision_std": np.std(cvres["test_precision"], ddof=1),
                "Recall_mean":   np.mean(cvres["test_recall"]),
                "Recall_std":    np.std(cvres["test_recall"], ddof=1),
                "FitTime_mean":  np.mean(cvres["fit_time"]),
                "FitTime_std":   np.std(cvres["fit_time"], ddof=1),
                "ScoreTime_mean":np.mean(cvres["score_time"]),
                "ScoreTime_std": np.std(cvres["score_time"], ddof=1),
            })

        # ==============================
        # SALVAR RESULTADOS (SUMMARY)
        # ==============================
        df_summary = (
            pd.DataFrame(summary_rows)
            .sort_values("F1_mean", ascending=False)
            .reset_index(drop=True)
        )

        safe = model_name.replace("/", "_")
        path_summary = f"Resultados/Embedding_{safe}_{balance_name}.csv"
        df_summary.to_csv(path_summary, index=False)
        print(f"[OK] Resumo salvo em: {path_summary}")
        print(df_summary.head(3))

        # ==============================
        # SALVAR RESULTADOS POR FOLD
        # ==============================
        df_folds = pd.DataFrame(fold_rows)
        path_folds = f"Resultados_folds/Embedding_{safe}_{balance_name}_folds.csv"
        df_folds.to_csv(path_folds, index=False)

        print(f"[OK] Folds salvos em: {path_folds}")
# Out:
# Carregando modelo: DeepChem/ChemBERTa-77M-MTR
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# Some weights of RobertaModel were not initialized from the model checkpoint at DeepChem/ChemBERTa-77M-MTR and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Embeddings DeepChem/ChemBERTa-77M-MTR: 100%|██████████| 2090/2090 [00:03<00:00, 577.60it/s]
# Rodando sampling original no modelo DeepChem/ChemBERTa-77M-MTR
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-77M-MTR_original.csv
#                EmbeddingModel   Balance     Model  Accuracy_mean  \
# 0  DeepChem/ChemBERTa-77M-MTR  original   XGBoost       0.803349
# 1  DeepChem/ChemBERTa-77M-MTR  original  CatBoost       0.801435
# 2  DeepChem/ChemBERTa-77M-MTR  original  LightGBM       0.797129
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.019462     0.772175    0.029561  0.710666  0.048396      0.847973
# 1      0.025040     0.770237    0.029860  0.707623  0.045433      0.843544
# 2      0.024933     0.767973    0.032698  0.705371  0.050303      0.841123
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.028747        0.809852       0.052165     0.636214    0.063501
# 1     0.023372        0.812937       0.059903     0.630672    0.064086
# 2     0.028302        0.792964       0.052855     0.638780    0.068976
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0     22.650980     0.368559        0.015790       0.005198
# 1     46.544842     9.676243        0.016853       0.004594
# 2     17.066160     0.190371        0.020264       0.002638
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-77M-MTR_original_folds.csv
#
# Rodando sampling under no modelo DeepChem/ChemBERTa-77M-MTR
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-77M-MTR_under.csv
#                EmbeddingModel Balance       Model  Accuracy_mean  \
# 0  DeepChem/ChemBERTa-77M-MTR   under  ExtraTrees       0.782775
# 1  DeepChem/ChemBERTa-77M-MTR   under       NuSVC       0.772249
# 2  DeepChem/ChemBERTa-77M-MTR   under    LightGBM       0.770335
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.023134     0.767384    0.030100  0.710610  0.039710      0.830866
# 1      0.032545     0.764054    0.036964  0.709716  0.049091      0.831214
# 2      0.029148     0.762850    0.032076  0.709086  0.038668      0.830092
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.023501        0.724880       0.032459     0.699835    0.066274
# 1     0.032796        0.692699       0.048994     0.729880    0.064583
# 2     0.028373        0.689399       0.034737     0.731911    0.057937
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      0.656735     0.182327        0.214870       0.138475
# 1      0.221035     0.026227        0.067412       0.011416
# 2     16.744211     0.442277        0.018908       0.003106
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-77M-MTR_under_folds.csv
#
# Rodando sampling over no modelo DeepChem/ChemBERTa-77M-MTR
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-77M-MTR_over.csv
#                EmbeddingModel Balance     Model  Accuracy_mean  Accuracy_std  \
# 0  DeepChem/ChemBERTa-77M-MTR    over   XGBoost       0.803828      0.017903
# 1  DeepChem/ChemBERTa-77M-MTR    over  CatBoost       0.797129      0.023244
# 2  DeepChem/ChemBERTa-77M-MTR    over     NuSVC       0.783254      0.031662
#
#    BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  ROC_AUC_std  \
# 0     0.778697    0.022285  0.721819  0.034648      0.846484     0.025770
# 1     0.771331    0.023729  0.712121  0.033344      0.839142     0.029093
# 2     0.766612    0.035553  0.709486  0.049271      0.838772     0.035952
#
#    Precision_mean  Precision_std  Recall_mean  Recall_std  FitTime_mean  \
# 0        0.790760       0.057313     0.667015    0.047582     24.611356
# 1        0.784390       0.051541     0.656718    0.058122     32.211854
# 2        0.728624       0.053528     0.693227    0.058201      0.901693
#
#    FitTime_std  ScoreTime_mean  ScoreTime_std
# 0     0.247502        0.021951       0.005880
# 1    13.567805        0.018544       0.004015
# 2     0.298568        0.154389       0.065012
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-77M-MTR_over_folds.csv
#
# Rodando sampling smooth no modelo DeepChem/ChemBERTa-77M-MTR
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-77M-MTR_smooth.csv
#                EmbeddingModel Balance     Model  Accuracy_mean  Accuracy_std  \
# 0  DeepChem/ChemBERTa-77M-MTR  smooth   XGBoost       0.802392      0.022105
# 1  DeepChem/ChemBERTa-77M-MTR  smooth  CatBoost       0.799043      0.020174
# 2  DeepChem/ChemBERTa-77M-MTR  smooth  LightGBM       0.796651      0.021308
#
#    BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  ROC_AUC_std  \
# 0     0.780886    0.032059  0.725023  0.050515      0.845299     0.033017
# 1     0.778038    0.026568  0.721758  0.040374      0.841834     0.027912
# 2     0.773330    0.033419  0.714252  0.053180      0.844137     0.028981
#
#    Precision_mean  Precision_std  Recall_mean  Recall_std  FitTime_mean  \
# 0        0.772417       0.053433     0.687170    0.071502     25.045020
# 1        0.767823       0.045341     0.684717    0.062984     37.619737
# 2        0.768426       0.044276     0.672318    0.082052     20.701811
#
#    FitTime_std  ScoreTime_mean  ScoreTime_std
# 0     0.296795        0.021041       0.009286
# 1    15.396343        0.017302       0.005482
# 2     0.449795        0.019086       0.003595
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-77M-MTR_smooth_folds.csv
#
# Carregando modelo: DeepChem/ChemBERTa-77M-MLM
# Some weights of RobertaModel were not initialized from the model checkpoint at DeepChem/ChemBERTa-77M-MLM and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Embeddings DeepChem/ChemBERTa-77M-MLM: 100%|██████████| 2090/2090 [00:03<00:00, 624.56it/s]
# Rodando sampling original no modelo DeepChem/ChemBERTa-77M-MLM
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-77M-MLM_original.csv
#                EmbeddingModel   Balance     Model  Accuracy_mean  \
# 0  DeepChem/ChemBERTa-77M-MLM  original     NuSVC       0.787081
# 1  DeepChem/ChemBERTa-77M-MLM  original  LightGBM       0.789474
# 2  DeepChem/ChemBERTa-77M-MLM  original   XGBoost       0.786603
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.036873     0.763175    0.042469  0.702607  0.063133      0.847147
# 1      0.029148     0.761084    0.028173  0.698640  0.038184      0.843359
# 2      0.032467     0.757327    0.033851  0.692493  0.048144      0.842501
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.035723        0.752695       0.058679     0.661993    0.079767
# 1     0.027883        0.775431       0.034106     0.637655    0.054154
# 2     0.030843        0.773334       0.044192     0.629060    0.061751
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      1.823654     0.020279        0.171019       0.025309
# 1     20.710740     0.446988        0.019011       0.003040
# 2     23.590889     0.344933        0.022456       0.006437
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-77M-MLM_original_folds.csv
#
# Rodando sampling under no modelo DeepChem/ChemBERTa-77M-MLM
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-77M-MLM_under.csv
#                EmbeddingModel Balance    Model  Accuracy_mean  Accuracy_std  \
# 0  DeepChem/ChemBERTa-77M-MLM   under    NuSVC       0.781340      0.019012
# 1  DeepChem/ChemBERTa-77M-MLM   under      SVC       0.771770      0.029927
# 2  DeepChem/ChemBERTa-77M-MLM   under  XGBoost       0.767943      0.031274
#
#    BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  ROC_AUC_std  \
# 0     0.780034    0.023343  0.730005  0.033429      0.845709     0.027432
# 1     0.766335    0.035685  0.712737  0.047659      0.835620     0.026616
# 2     0.764092    0.032907  0.711615  0.042096      0.833479     0.031491
#
#    Precision_mean  Precision_std  Recall_mean  Recall_std  FitTime_mean  \
# 0        0.691823       0.036005     0.774884    0.052827      0.646644
# 1        0.685898       0.042369     0.743625    0.065982      0.747885
# 2        0.679322       0.048984     0.748616    0.046943     21.223142
#
#    FitTime_std  ScoreTime_mean  ScoreTime_std
# 0     0.165780        0.138042       0.077591
# 1     0.135599        0.134297       0.055935
# 2     0.328676        0.024183       0.004434
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-77M-MLM_under_folds.csv
#
# Rodando sampling over no modelo DeepChem/ChemBERTa-77M-MLM
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-77M-MLM_over.csv
#                EmbeddingModel Balance    Model  Accuracy_mean  Accuracy_std  \
# 0  DeepChem/ChemBERTa-77M-MLM    over      SVC       0.788517      0.030076
# 1  DeepChem/ChemBERTa-77M-MLM    over    NuSVC       0.788517      0.030412
# 2  DeepChem/ChemBERTa-77M-MLM    over  XGBoost       0.797129      0.028637
#
#    BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  ROC_AUC_std  \
# 0     0.776213    0.035638  0.722403  0.050244      0.844753     0.031307
# 1     0.775898    0.035980  0.722200  0.050965      0.850166     0.032725
# 2     0.769922    0.030239  0.710990  0.042706      0.845312     0.033019
#
#    Precision_mean  Precision_std  Recall_mean  Recall_std  FitTime_mean  \
# 0        0.724586       0.053063     0.722506    0.063623      1.625063
# 1        0.724784       0.054562     0.721949    0.064168      2.250624
# 2        0.783053       0.045289     0.652860    0.054292     24.229862
#
#    FitTime_std  ScoreTime_mean  ScoreTime_std
# 0     0.352407        0.168867       0.052742
# 1     0.103619        0.187693       0.056029
# 2     0.444394        0.022484       0.007629
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-77M-MLM_over_folds.csv
#
# Rodando sampling smooth no modelo DeepChem/ChemBERTa-77M-MLM
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-77M-MLM_smooth.csv
#                EmbeddingModel Balance     Model  Accuracy_mean  Accuracy_std  \
# 0  DeepChem/ChemBERTa-77M-MLM  smooth     NuSVC       0.789952      0.037705
# 1  DeepChem/ChemBERTa-77M-MLM  smooth       SVC       0.784211      0.030798
# 2  DeepChem/ChemBERTa-77M-MLM  smooth  LightGBM       0.790909      0.031662
#
#    BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  ROC_AUC_std  \
# 0     0.777974    0.041968  0.725502  0.058574      0.846202     0.037588
# 1     0.770456    0.038921  0.715255  0.057753      0.840506     0.036182
# 2     0.768124    0.030397  0.710593  0.038671      0.843749     0.033667
#
#    Precision_mean  Precision_std  Recall_mean  Recall_std  FitTime_mean  \
# 0        0.725214       0.065741     0.727768    0.064432      1.705061
# 1        0.718614       0.054761     0.713587    0.070510      1.611724
# 2        0.759236       0.041741     0.668937    0.046138     18.021249
#
#    FitTime_std  ScoreTime_mean  ScoreTime_std
# 0     0.235094        0.161562       0.045171
# 1     0.194231        0.207660       0.083743
# 2     0.210258        0.018489       0.002712
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-77M-MLM_smooth_folds.csv
#
# Carregando modelo: DeepChem/ChemBERTa-100M-MLM
# Some weights of RobertaModel were not initialized from the model checkpoint at DeepChem/ChemBERTa-100M-MLM and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Embeddings DeepChem/ChemBERTa-100M-MLM:   0%|          | 0/2090 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Embeddings DeepChem/ChemBERTa-100M-MLM: 100%|██████████| 2090/2090 [00:08<00:00, 240.63it/s]
# Rodando sampling original no modelo DeepChem/ChemBERTa-100M-MLM
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-100M-MLM_original.csv
#                 EmbeddingModel   Balance          Model  Accuracy_mean  \
# 0  DeepChem/ChemBERTa-100M-MLM  original          NuSVC       0.769378
# 1  DeepChem/ChemBERTa-100M-MLM  original  MLPClassifier       0.752632
# 2  DeepChem/ChemBERTa-100M-MLM  original     KNeighbors       0.746890
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.038989     0.742871    0.040779  0.674199  0.055872      0.820064
# 1      0.039907     0.736783    0.036022  0.673590  0.042565      0.811502
# 2      0.035265     0.728004    0.035904  0.661189  0.047598      0.790739
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.034581        0.736008       0.053720     0.624895    0.070970
# 1     0.038106        0.688123       0.064419     0.664079    0.052781
# 2     0.043764        0.680764       0.058265     0.645058    0.053826
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      2.501170     0.403622        0.433274       0.254226
# 1      4.514934     0.573888        0.015205       0.007777
# 2      0.045111     0.001403        0.046649       0.001692
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-100M-MLM_original_folds.csv
#
# Rodando sampling under no modelo DeepChem/ChemBERTa-100M-MLM
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-100M-MLM_under.csv
#                 EmbeddingModel Balance     Model  Accuracy_mean  Accuracy_std  \
# 0  DeepChem/ChemBERTa-100M-MLM   under  LightGBM       0.744498      0.036731
# 1  DeepChem/ChemBERTa-100M-MLM   under     NuSVC       0.742105      0.029447
# 2  DeepChem/ChemBERTa-100M-MLM   under   XGBoost       0.744019      0.038294
#
#    BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  ROC_AUC_std  \
# 0     0.740096    0.036384  0.683234  0.042006      0.806700     0.041558
# 1     0.738820    0.031896  0.682411  0.045130      0.814977     0.035923
# 2     0.737899    0.040829  0.680236  0.055427      0.812748     0.040934
#
#    Precision_mean  Precision_std  Recall_mean  Recall_std  FitTime_mean  \
# 0        0.653268       0.053742     0.718928    0.049040     44.412853
# 1        0.645283       0.054083     0.725467    0.044913      0.945001
# 2        0.652024       0.063201     0.712865    0.057315     47.706355
#
#    FitTime_std  ScoreTime_mean  ScoreTime_std
# 0     1.174525        0.025734       0.004201
# 1     0.137017        0.312637       0.099573
# 2     0.282827        0.026039       0.005052
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-100M-MLM_under_folds.csv
#
# Rodando sampling over no modelo DeepChem/ChemBERTa-100M-MLM
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-100M-MLM_over.csv
#                 EmbeddingModel Balance          Model  Accuracy_mean  \
# 0  DeepChem/ChemBERTa-100M-MLM    over          NuSVC       0.758852
# 1  DeepChem/ChemBERTa-100M-MLM    over            SVC       0.755502
# 2  DeepChem/ChemBERTa-100M-MLM    over  MLPClassifier       0.752632
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.033622     0.746799    0.034175  0.688021  0.043351      0.821268
# 1      0.031854     0.743727    0.033460  0.684403  0.044886      0.813507
# 2      0.048588     0.737561    0.046653  0.674699  0.054346      0.812369
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.037142        0.683510       0.053122     0.694325    0.047240
# 1     0.033146        0.677257       0.054190     0.692727    0.042908
# 2     0.042709        0.686313       0.067506     0.668194    0.068928
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      5.010761     0.042958        0.575661       0.025909
# 1      4.738496     0.045685        0.660613       0.031620
# 2      2.750160     0.403921        0.013277       0.004141
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-100M-MLM_over_folds.csv
#
# Rodando sampling smooth no modelo DeepChem/ChemBERTa-100M-MLM
# [OK] Resumo salvo em: Resultados/Embedding_DeepChem_ChemBERTa-100M-MLM_smooth.csv
#                 EmbeddingModel Balance     Model  Accuracy_mean  Accuracy_std  \
# 0  DeepChem/ChemBERTa-100M-MLM  smooth     NuSVC       0.761244      0.035481
# 1  DeepChem/ChemBERTa-100M-MLM  smooth       SVC       0.761244      0.034314
# 2  DeepChem/ChemBERTa-100M-MLM  smooth  LightGBM       0.767943      0.037353
#
#    BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  ROC_AUC_std  \
# 0     0.748239    0.037278  0.689059  0.050075      0.821390     0.038742
# 1     0.745639    0.038929  0.684623  0.054929      0.812789     0.036989
# 2     0.746318    0.035983  0.682865  0.045786      0.814099     0.041343
#
#    Precision_mean  Precision_std  Recall_mean  Recall_std  FitTime_mean  \
# 0        0.688302       0.062596     0.691381    0.047980      4.961904
# 1        0.691401       0.058887     0.679435    0.060721      4.646333
# 2        0.719738       0.056903     0.651413    0.048752     42.160041
#
#    FitTime_std  ScoreTime_mean  ScoreTime_std
# 0     0.053784        0.541735       0.035997
# 1     0.054433        0.589128       0.035366
# 2     1.152193        0.024434       0.003422
# [OK] Folds salvos em: Resultados_folds/Embedding_DeepChem_ChemBERTa-100M-MLM_smooth_folds.csv
#
# Carregando modelo: ibm-research/MoLFormer-XL-both-10pct
# Embeddings ibm-research/MoLFormer-XL-both-10pct:   0%|          | 0/2090 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Embeddings ibm-research/MoLFormer-XL-both-10pct: 100%|██████████| 2090/2090 [00:28<00:00, 72.50it/s]
# Rodando sampling original no modelo ibm-research/MoLFormer-XL-both-10pct
# [OK] Resumo salvo em: Resultados/Embedding_ibm-research_MoLFormer-XL-both-10pct_original.csv
#                          EmbeddingModel   Balance          Model  \
# 0  ibm-research/MoLFormer-XL-both-10pct  original          NuSVC
# 1  ibm-research/MoLFormer-XL-both-10pct  original  MLPClassifier
# 2  ibm-research/MoLFormer-XL-both-10pct  original     KNeighbors
#
#    Accuracy_mean  Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  \
# 0       0.783254      0.028446     0.758938    0.028945  0.697770  0.039326
# 1       0.762679      0.033470     0.746405    0.038256  0.685260  0.053690
# 2       0.762679      0.031914     0.746053    0.037430  0.682775  0.055658
#
#    ROC_AUC_mean  ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  \
# 0      0.839889     0.033663        0.750112       0.038823     0.653584
# 1      0.811506     0.047579        0.694913       0.055790     0.677255
# 2      0.814163     0.023399        0.699612       0.070268     0.671494
#
#    Recall_std  FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0    0.049849      2.833006     0.343741        0.512047       0.242220
# 1    0.060691      3.562244     0.073132        0.015301       0.006212
# 2    0.070909      0.042941     0.000000        0.049859       0.000000
# [OK] Folds salvos em: Resultados_folds/Embedding_ibm-research_MoLFormer-XL-both-10pct_original_folds.csv
#
# Rodando sampling under no modelo ibm-research/MoLFormer-XL-both-10pct
# [OK] Resumo salvo em: Resultados/Embedding_ibm-research_MoLFormer-XL-both-10pct_under.csv
#                          EmbeddingModel Balance       Model  Accuracy_mean  \
# 0  ibm-research/MoLFormer-XL-both-10pct   under       NuSVC       0.767464
# 1  ibm-research/MoLFormer-XL-both-10pct   under         SVC       0.762201
# 2  ibm-research/MoLFormer-XL-both-10pct   under  ExtraTrees       0.759330
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.036523     0.766643    0.042278  0.714315  0.052601      0.835095
# 1      0.032690     0.754365    0.037525  0.698118  0.045848      0.824680
# 2      0.025423     0.746725    0.027277  0.687639  0.032560      0.817493
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.030823        0.673971       0.050015     0.762068    0.069945
# 1     0.031248        0.679354       0.037582     0.720102    0.067632
# 2     0.026686        0.684401       0.023923     0.692494    0.052265
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      0.877285     0.271606        0.389217       0.192594
# 1      0.883172     0.137033        0.384492       0.106173
# 2      1.138707     0.024590        0.108886       0.032810
# [OK] Folds salvos em: Resultados_folds/Embedding_ibm-research_MoLFormer-XL-both-10pct_under_folds.csv
#
# Rodando sampling over no modelo ibm-research/MoLFormer-XL-both-10pct
# [OK] Resumo salvo em: Resultados/Embedding_ibm-research_MoLFormer-XL-both-10pct_over.csv
#                          EmbeddingModel Balance       Model  Accuracy_mean  \
# 0  ibm-research/MoLFormer-XL-both-10pct    over       NuSVC       0.782297
# 1  ibm-research/MoLFormer-XL-both-10pct    over         SVC       0.780383
# 2  ibm-research/MoLFormer-XL-both-10pct    over  KNeighbors       0.730622
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.040047     0.769040    0.044071  0.713638  0.054803      0.843716
# 1      0.034091     0.765583    0.037454  0.709075  0.049899      0.836845
# 2      0.029326     0.734278    0.031639  0.678995  0.045443      0.805702
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.033617        0.719293       0.048841     0.710298    0.072837
# 1     0.032579        0.719474       0.051201     0.700813    0.061232
# 2     0.024043        0.625970       0.060218     0.746752    0.060307
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      5.197220     0.054752        0.666942       0.034017
# 1      4.718118     0.089986        0.677324       0.056406
# 2      0.055335     0.001292        0.052088       0.002404
# [OK] Folds salvos em: Resultados_folds/Embedding_ibm-research_MoLFormer-XL-both-10pct_over_folds.csv
#
# Rodando sampling smooth no modelo ibm-research/MoLFormer-XL-both-10pct
# [OK] Resumo salvo em: Resultados/Embedding_ibm-research_MoLFormer-XL-both-10pct_smooth.csv
#                          EmbeddingModel Balance          Model  Accuracy_mean  \
# 0  ibm-research/MoLFormer-XL-both-10pct  smooth          NuSVC       0.787560
# 1  ibm-research/MoLFormer-XL-both-10pct  smooth            SVC       0.776077
# 2  ibm-research/MoLFormer-XL-both-10pct  smooth  MLPClassifier       0.760287
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.029252     0.774031    0.031473  0.719915  0.041292      0.841700
# 1      0.030579     0.760211    0.032226  0.702380  0.043844      0.835159
# 2      0.044569     0.745392    0.050314  0.684461  0.069593      0.811143
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.034586        0.728491       0.050818     0.713599    0.050073
# 1     0.033457        0.716745       0.055451     0.690676    0.049733
# 2     0.052547        0.688513       0.073968     0.681901    0.073163
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      5.133632     0.047386        0.622527       0.031056
# 1      4.661724     0.050610        0.613722       0.021228
# 2      2.182296     0.072256        0.015312       0.004174
# [OK] Folds salvos em: Resultados_folds/Embedding_ibm-research_MoLFormer-XL-both-10pct_smooth_folds.csv
#
# Carregando modelo: seyonec/ChemBERTa-zinc-base-v1
# Embeddings seyonec/ChemBERTa-zinc-base-v1: 100%|██████████| 2090/2090 [00:05<00:00, 403.68it/s]
# Rodando sampling original no modelo seyonec/ChemBERTa-zinc-base-v1
# [OK] Resumo salvo em: Resultados/Embedding_seyonec_ChemBERTa-zinc-base-v1_original.csv
#                    EmbeddingModel   Balance     Model  Accuracy_mean  \
# 0  seyonec/ChemBERTa-zinc-base-v1  original     NuSVC       0.747368
# 1  seyonec/ChemBERTa-zinc-base-v1  original   XGBoost       0.750239
# 2  seyonec/ChemBERTa-zinc-base-v1  original  LightGBM       0.750718
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.033667     0.721325    0.035911  0.647385  0.050575      0.798741
# 1      0.022533     0.717155    0.026589  0.634628  0.040745      0.804977
# 2      0.027481     0.716544    0.031338  0.632324  0.050671      0.798863
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.027907        0.696751       0.058986     0.606579    0.057381
# 1     0.032709        0.723552       0.049618     0.568937    0.060739
# 2     0.033714        0.727962       0.044677     0.564062    0.074825
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      3.357623     0.055075        0.452834       0.031722
# 1     54.473177     0.339588        0.026445       0.006952
# 2     58.539316     0.805416        0.023966       0.003198
# [OK] Folds salvos em: Resultados_folds/Embedding_seyonec_ChemBERTa-zinc-base-v1_original_folds.csv
#
# Rodando sampling under no modelo seyonec/ChemBERTa-zinc-base-v1
# [OK] Resumo salvo em: Resultados/Embedding_seyonec_ChemBERTa-zinc-base-v1_under.csv
#                    EmbeddingModel Balance     Model  Accuracy_mean  \
# 0  seyonec/ChemBERTa-zinc-base-v1   under   XGBoost       0.730622
# 1  seyonec/ChemBERTa-zinc-base-v1   under  LightGBM       0.727751
# 2  seyonec/ChemBERTa-zinc-base-v1   under     NuSVC       0.717703
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.025423     0.728403    0.028672  0.669463  0.039531      0.800489
# 1      0.024857     0.724549    0.030631  0.663548  0.042120      0.797131
# 2      0.027066     0.718580    0.030266  0.661182  0.042509      0.792833
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.029717        0.632989       0.049162     0.715202    0.063394
# 1     0.027895        0.631441       0.049186     0.705706    0.077433
# 2     0.026844        0.612580       0.049379     0.721655    0.058339
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0     48.684058     0.534539        0.024359       0.008976
# 1     38.959801     0.966046        0.023154       0.002727
# 2      0.933836     0.120808        0.321903       0.084743
# [OK] Folds salvos em: Resultados_folds/Embedding_seyonec_ChemBERTa-zinc-base-v1_under_folds.csv
#
# Rodando sampling over no modelo seyonec/ChemBERTa-zinc-base-v1
# [OK] Resumo salvo em: Resultados/Embedding_seyonec_ChemBERTa-zinc-base-v1_over.csv
#                    EmbeddingModel Balance    Model  Accuracy_mean  \
# 0  seyonec/ChemBERTa-zinc-base-v1    over      SVC       0.736364
# 1  seyonec/ChemBERTa-zinc-base-v1    over    NuSVC       0.734928
# 2  seyonec/ChemBERTa-zinc-base-v1    over  XGBoost       0.751196
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.036818     0.723757    0.040272  0.659830  0.051621      0.790753
# 1      0.036731     0.723315    0.040958  0.659117  0.052625      0.802474
# 2      0.022668     0.720539    0.028573  0.641575  0.045806      0.802100
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.037745        0.652513       0.051455     0.669550    0.066035
# 1     0.031706        0.650039       0.054850     0.671385    0.068974
# 2     0.036534        0.716654       0.067868     0.583807    0.052139
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      4.803188     0.026874        0.669535       0.019233
# 1      5.062301     0.054186        0.567612       0.027289
# 2     56.757348     0.848207        0.028954       0.006330
# [OK] Folds salvos em: Resultados_folds/Embedding_seyonec_ChemBERTa-zinc-base-v1_over_folds.csv
#
# Rodando sampling smooth no modelo seyonec/ChemBERTa-zinc-base-v1
# [OK] Resumo salvo em: Resultados/Embedding_seyonec_ChemBERTa-zinc-base-v1_smooth.csv
#                    EmbeddingModel Balance    Model  Accuracy_mean  \
# 0  seyonec/ChemBERTa-zinc-base-v1  smooth    NuSVC       0.740191
# 1  seyonec/ChemBERTa-zinc-base-v1  smooth      SVC       0.739713
# 2  seyonec/ChemBERTa-zinc-base-v1  smooth  XGBoost       0.749282
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.037746     0.726340    0.044290  0.661048  0.059254      0.801807
# 1      0.036523     0.724295    0.040316  0.657495  0.051760      0.793435
# 2      0.032152     0.724295    0.036608  0.650023  0.052734      0.800497
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.032506        0.659851       0.060628     0.664753    0.073339
# 1     0.032516        0.663453       0.051370     0.654595    0.069522
# 2     0.037150        0.699117       0.054377     0.611368    0.072482
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      5.057659     0.054451        0.545038       0.032633
# 1      4.680184     0.070387        0.624273       0.046949
# 2     57.176775     0.474348        0.027855       0.003595
# [OK] Folds salvos em: Resultados_folds/Embedding_seyonec_ChemBERTa-zinc-base-v1_smooth_folds.csv
#
# Carregando modelo: alvaroalon2/biobert_chemical_ner
# Some weights of BertModel were not initialized from the model checkpoint at alvaroalon2/biobert_chemical_ner and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Embeddings alvaroalon2/biobert_chemical_ner: 100%|██████████| 2090/2090 [00:08<00:00, 234.94it/s]
# Rodando sampling original no modelo alvaroalon2/biobert_chemical_ner
# [OK] Resumo salvo em: Resultados/Embedding_alvaroalon2_biobert_chemical_ner_original.csv
#                      EmbeddingModel   Balance               Model  \
# 0  alvaroalon2/biobert_chemical_ner  original               NuSVC
# 1  alvaroalon2/biobert_chemical_ner  original       MLPClassifier
# 2  alvaroalon2/biobert_chemical_ner  original  LogisticRegression
#
#    Accuracy_mean  Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  \
# 0       0.727273      0.050636     0.695657    0.058172  0.607498  0.088033
# 1       0.710526      0.044213     0.686740    0.044662  0.606384  0.063598
# 2       0.692823      0.035791     0.668453    0.034921  0.583921  0.046911
#
#    ROC_AUC_mean  ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  \
# 0      0.765314     0.048899        0.677850       0.105036     0.555249
# 1      0.739421     0.049251        0.640587       0.094298     0.583626
# 2      0.726489     0.049750        0.609623       0.062116     0.562592
#
#    Recall_std  FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0    0.093234      1.811594     0.498065        0.305699       0.166923
# 1    0.076868      4.864077     0.792172        0.010881       0.002770
# 2    0.048465      1.315557     0.294405        0.014280       0.005245
# [OK] Folds salvos em: Resultados_folds/Embedding_alvaroalon2_biobert_chemical_ner_original_folds.csv
#
# Rodando sampling under no modelo alvaroalon2/biobert_chemical_ner
# [OK] Resumo salvo em: Resultados/Embedding_alvaroalon2_biobert_chemical_ner_under.csv
#                      EmbeddingModel Balance          Model  Accuracy_mean  \
# 0  alvaroalon2/biobert_chemical_ner   under          NuSVC       0.685646
# 1  alvaroalon2/biobert_chemical_ner   under  MLPClassifier       0.674163
# 2  alvaroalon2/biobert_chemical_ner   under       LightGBM       0.676077
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.041837     0.681162    0.046467  0.616978  0.062280      0.748029
# 1      0.046194     0.673646    0.040932  0.611615  0.048755      0.725233
# 2      0.041837     0.672276    0.043389  0.607171  0.054933      0.731102
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.052714        0.578888       0.066234     0.663285    0.072662
# 1     0.052455        0.569134       0.074783     0.667450    0.043786
# 2     0.058623        0.569448       0.064933     0.655369    0.069622
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      1.024525     0.291804        0.320461       0.193678
# 1      2.508417     0.605335        0.015404       0.004052
# 2     45.832550     0.189241        0.030019       0.004982
# [OK] Folds salvos em: Resultados_folds/Embedding_alvaroalon2_biobert_chemical_ner_under_folds.csv
#
# Rodando sampling over no modelo alvaroalon2/biobert_chemical_ner
# [OK] Resumo salvo em: Resultados/Embedding_alvaroalon2_biobert_chemical_ner_over.csv
#                      EmbeddingModel Balance            Model  Accuracy_mean  \
# 0  alvaroalon2/biobert_chemical_ner    over    MLPClassifier       0.709091
# 1  alvaroalon2/biobert_chemical_ner    over            NuSVC       0.710526
# 2  alvaroalon2/biobert_chemical_ner    over  RidgeClassifier       0.668421
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.039249     0.690045    0.043870  0.612992  0.066223      0.740229
# 1      0.050448     0.687618    0.055857  0.607418  0.078339      0.757797
# 2      0.051781     0.660151    0.053652  0.590199  0.066480      0.701174
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.042247        0.628699       0.085951     0.605425    0.082999
# 1     0.050536        0.634830       0.096278     0.586811    0.083479
# 2     0.047697        0.562876       0.076739     0.623199    0.066067
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      4.945292     0.590895        0.015411       0.005784
# 1      5.674421     0.090583        0.653515       0.056042
# 2      0.099206     0.002609        0.014180       0.001166
# [OK] Folds salvos em: Resultados_folds/Embedding_alvaroalon2_biobert_chemical_ner_over_folds.csv
#
# Rodando sampling smooth no modelo alvaroalon2/biobert_chemical_ner
# [OK] Resumo salvo em: Resultados/Embedding_alvaroalon2_biobert_chemical_ner_smooth.csv
#                      EmbeddingModel Balance          Model  Accuracy_mean  \
# 0  alvaroalon2/biobert_chemical_ner  smooth          NuSVC       0.721531
# 1  alvaroalon2/biobert_chemical_ner  smooth  MLPClassifier       0.705263
# 2  alvaroalon2/biobert_chemical_ner  smooth     KNeighbors       0.631100
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.044589     0.701296    0.048859  0.627303  0.068704      0.759700
# 1      0.048017     0.684200    0.052249  0.606017  0.073569      0.738350
# 2      0.033184     0.647407    0.033758  0.599489  0.044556      0.700985
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.044830        0.645077       0.081883     0.613823    0.074398
# 1     0.052120        0.622658       0.086660     0.593462    0.076271
# 2     0.043388        0.514086       0.048322     0.721684    0.051861
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      5.663577     0.056604        0.598169       0.022765
# 1      3.644180     0.624249        0.014292       0.004689
# 2      0.083450     0.006081        0.050349       0.003390
# [OK] Folds salvos em: Resultados_folds/Embedding_alvaroalon2_biobert_chemical_ner_smooth_folds.csv
#
# Carregando modelo: google-bert/bert-base-uncased
# Embeddings google-bert/bert-base-uncased: 100%|██████████| 2090/2090 [01:05<00:00, 31.68it/s]
# Rodando sampling original no modelo google-bert/bert-base-uncased
# [OK] Resumo salvo em: Resultados/Embedding_google-bert_bert-base-uncased_original.csv
#                   EmbeddingModel   Balance          Model  Accuracy_mean  \
# 0  google-bert/bert-base-uncased  original  MLPClassifier       0.753589
# 1  google-bert/bert-base-uncased  original       LightGBM       0.766986
# 2  google-bert/bert-base-uncased  original          NuSVC       0.754545
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.041849     0.735088    0.043443  0.669113  0.056595      0.801841
# 1      0.038014     0.734986    0.041165  0.660031  0.061114      0.815869
# 2      0.034061     0.726044    0.034056  0.652500  0.047758      0.817004
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.037051        0.692486       0.066168     0.652198    0.075959
# 1     0.037653        0.747368       0.047160     0.594667    0.080980
# 2     0.040114        0.715734       0.053746     0.602741    0.063390
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      4.870420     0.361727        0.015818       0.004976
# 1     56.449268     1.137320        0.028251       0.006025
# 2      2.976992     0.428301        0.449663       0.228378
# [OK] Folds salvos em: Resultados_folds/Embedding_google-bert_bert-base-uncased_original_folds.csv
#
# Rodando sampling under no modelo google-bert/bert-base-uncased
# [OK] Resumo salvo em: Resultados/Embedding_google-bert_bert-base-uncased_under.csv
#                   EmbeddingModel Balance     Model  Accuracy_mean  \
# 0  google-bert/bert-base-uncased   under   XGBoost       0.754067
# 1  google-bert/bert-base-uncased   under  LightGBM       0.751196
# 2  google-bert/bert-base-uncased   under     NuSVC       0.743062
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.039917     0.747847    0.044601  0.690763  0.057738      0.818907
# 1      0.039391     0.745499    0.043661  0.687901  0.057293      0.818162
# 2      0.029326     0.739542    0.030040  0.683282  0.038803      0.807902
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.038226        0.667183       0.062007     0.719670    0.074547
# 1     0.037935        0.663062       0.061000     0.719588    0.081020
# 2     0.037047        0.649093       0.049861     0.724284    0.049831
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0     50.325283     0.797455        0.026628       0.006484
# 1     45.230749     1.749112        0.026506       0.005060
# 2      1.033862     0.373485        0.343987       0.231300
# [OK] Folds salvos em: Resultados_folds/Embedding_google-bert_bert-base-uncased_under_folds.csv
#
# Rodando sampling over no modelo google-bert/bert-base-uncased
# [OK] Resumo salvo em: Resultados/Embedding_google-bert_bert-base-uncased_over.csv
#                   EmbeddingModel Balance          Model  Accuracy_mean  \
# 0  google-bert/bert-base-uncased    over            SVC       0.762679
# 1  google-bert/bert-base-uncased    over          NuSVC       0.758373
# 2  google-bert/bert-base-uncased    over  MLPClassifier       0.751675
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.034370     0.747768    0.035604  0.687264  0.043587      0.811188
# 1      0.033245     0.744799    0.036126  0.683793  0.046760      0.817171
# 2      0.029187     0.734945    0.029262  0.670246  0.039543      0.798823
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.032017        0.695766       0.043638     0.681814    0.062530
# 1     0.036385        0.687092       0.050626     0.684097    0.066354
# 2     0.034747        0.685425       0.053731     0.660393    0.062554
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0      5.048471     0.072523        0.711248       0.057936
# 1      5.124680     0.442716        0.591489       0.294604
# 2      3.023592     0.436303        0.015246       0.005383
# [OK] Folds salvos em: Resultados_folds/Embedding_google-bert_bert-base-uncased_over_folds.csv
#
# Rodando sampling smooth no modelo google-bert/bert-base-uncased
# [OK] Resumo salvo em: Resultados/Embedding_google-bert_bert-base-uncased_smooth.csv
#                   EmbeddingModel Balance     Model  Accuracy_mean  \
# 0  google-bert/bert-base-uncased  smooth  CatBoost       0.770813
# 1  google-bert/bert-base-uncased  smooth     NuSVC       0.754067
# 2  google-bert/bert-base-uncased  smooth   XGBoost       0.768421
#
#    Accuracy_std  BalAcc_mean  BalAcc_std   F1_mean    F1_std  ROC_AUC_mean  \
# 0      0.035337     0.746804    0.039315  0.681018  0.056996      0.812291
# 1      0.031107     0.739065    0.032022  0.677750  0.040184      0.815581
# 2      0.040044     0.742857    0.045949  0.673739  0.065242      0.821482
#
#    ROC_AUC_std  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0     0.041195        0.729103       0.059031     0.642160    0.072508
# 1     0.038670        0.681844       0.041192     0.675795    0.055144
# 2     0.043760        0.729480       0.047307     0.630646    0.093060
#
#    FitTime_mean  FitTime_std  ScoreTime_mean  ScoreTime_std
# 0     84.898641    31.492614        0.048305       0.035672
# 1      5.596903     0.072980        0.639078       0.037223
# 2     58.521026     1.374868        0.023186       0.006204
# [OK] Folds salvos em: Resultados_folds/Embedding_google-bert_bert-base-uncased_smooth_folds.csv
